# %%
import pandas as pd
users_data=pd.read_csv("users_data.csv",index_col=0)
users_data
# Out:
#         Name  Age Gender Marital Status         City       Occupation  Salary  \
# 0       Mary   28      M       Divorced  Addis Ababa  Product Manager  286584
# 1   Napoleon   41      M         Single      Nairobi     Data Analyst   88044
# 2       Hill   36      M       Divorced  Addis Ababa          Plumber  101214
# 3    Wambley   32      M       Divorced      Kampala  Product Manager  242300
# 4      Ndege   29      M         Single  Addis Ababa  Product Manager  164752
# 5       Noel   42      M       Divorced        Dakar     Data Analyst   98984
# 6      Peter   28      M         Single        Dakar  Product Manager   90774
# 7       John   47      M         Single        Dakar  Product Manager   52568
# 8   Maryanne   40      F        Married        Dakar     Data Analyst  170151
# 9    Hillary   44      F         Single      Kampala     Data Analyst  243664
# 10    Marion   32      M        Married        Lagos          Teacher  248635
# ...
